# %% [markdown]
# <a href="https://colab.research.google.com/github/sahiltambe18/-HactoberFest2022-For_All_Beginers-/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/content/Cellphone.csv")
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
#gives the sum of null values in each attribute
df.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
#corelation between attr
df.corr()
# Out:
#               Product_id     Price      Sale    weight  resoloution       ppi  \
# Product_id      1.000000  0.165136  0.218548  0.035869    -0.017817  0.207271
# Price           0.165136  1.000000  0.273263  0.144555     0.404010  0.817614
# Sale            0.218548  0.273263  1.000000  0.016114     0.017154  0.235896
# weight          0.035869  0.144555  0.016114  1.000000     0.890416 -0.054683
# resoloution    -0.017817  0.404010  0.017154  0.890416     1.000000  0.181292
# ppi             0.207271  0.817614  0.235896 -0.054683     0.181292  1.000000
# cpu core       -0.008634  0.686811  0.069517  0.216257     0.472226  0.487990
# cpu freq        0.092428  0.727383  0.099133  0.222730     0.505454  0.713168
# internal mem    0.261186  0.776738  0.489308  0.098849     0.202660  0.618560
# ram             0.236194  0.896915  0.373127  0.149283     0.327216  0.748724
# RearCam         0.172812  0.739538  0.292164 -0.029448     0.249892  0.774008
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap="Purples")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
plt.scatter(df['Price'],df['ram'])
plt.xlabel(xlabel="price")
plt.ylabel(ylabel="Ram")
# Out:
# Text(0, 0.5, 'Ram')

# %%
plt.subplots(figsize=(10,10))
sns.regplot(data=df,x=df['Price'],y=df['ram'])
# Out:
# <Axes: xlabel='Price', ylabel='ram'>

# %%
sns.lmplot(x="Price",y="ppi",data=df,hue="cpu core",height=8)

# %%
pricer = df[df['ram']>=3]
pricer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    60 non-null     int64
#  1   Price         60 non-null     int64
#  2   Sale          60 non-null     int64
#  3   weight        60 non-null     float64
#  4   resoloution   60 non-null     float64
#  5   ppi           60 non-null     int64
#  6   cpu core      60 non-null     int64
#  7   cpu freq      60 non-null     float64
#  8   internal mem  60 non-null     float64
#  9   ram           60 non-null     float64
#  10  RearCam       60 non-null     float64
#  11  Front_Cam     60 non-null     float64
#  12  battery       60 non-null     int64
#  13  thickness     60 non-null     float64
# dtypes: float64(8), int64(6)
# memory usage: 7.0 KB

# %%
plt.subplots(figsize=(12,8))
sns.set_theme(style="darkgrid")
sns.distplot(pricer['Price'])
# Out:
# <ipython-input-56-aebffa36b3bc>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pricer['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.subplots(figsize=(12,8))
sns.set_theme(style="darkgrid")
sns.distplot(df['ram'])
# Out:
# <ipython-input-57-77a0d65878f7>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ram'])
# <Axes: xlabel='ram', ylabel='Density'>

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
x = df[['ram','battery','ppi','cpu core','cpu freq','internal mem',]]
y = df[['Price']]

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.25 , random_state=1)

# %%
print(f"sizes of splitted data")
print(f"x train {x_train.shape}")
print(f"x test {x_test.shape}")
print(f"y train {y_train.shape}")
print(f"y test {y_test.shape}")
# Out:
# sizes of splitted data
# x train (120, 6)
# x test (41, 6)
# y train (120, 1)
# y test (41, 1)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression

D_tree = DecisionTreeRegressor(random_state=1)
R_forest = RandomForestRegressor(random_state=1)
L_reg = LogisticRegression(random_state=1 , solver='lbfgs',max_iter=10000)

# %%
D_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
R_forest.fit(x_train,y_train)
# Out:
# <ipython-input-64-87872f44ef78>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   R_forest.fit(x_train,y_train)
# RandomForestRegressor(random_state=1)

# %%
L_reg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=10000, random_state=1)

# %%
y_pred_dt = D_tree.predict(x_test)
y_pred_rf = R_forest.predict(x_test)
y_pred_lr = L_reg.predict(x_test)
# result = pd.DataFrame({"actual":y_test ,"predicted": y_pred_dt})
# print(y_pred_dt)
y_test = y_test.astype(float)
y_pred_dt = y_pred_dt.astype(float)
# print(y_test)
y_test.info()
y_pred_dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 44 to 84
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   41 non-null     float64
# dtypes: float64(1)
# memory usage: 656.0 bytes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-42c8433b946b> in <cell line: 10>()
#       8 # print(y_test)
#       9 y_test.info()
# ---> 10 y_pred_dt.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'

# %%
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import classification_report

# print(classification_report(y_test,y_pred_dt))
# print(y_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred_dt)
plt.title('Decision Tree')
plt.show()
print(f" Accuracy is {accuracy_score(y_test,y_pred_dt)}")
print(classification_report(y_test,y_pred_dt))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-1b2e51914269> in <cell line: 1>()
# ----> 1 ConfusionMatrixDisplay.from_predictions(y_test,y_pred_dt)
#       2 plt.title('Decision Tree')
#       3 plt.show()
#       4 print(f" Accuracy is {accuracy_score(y_test,y_pred_dt)}")
#       5 print(classification_report(y_test,y_pred_dt))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in from_predictions(cls, y_true, y_pred, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar, im_kw, text_kw)
#     457         if display_labels is None:
#     458             if labels is None:
# --> 459                 display_labels = unique_labels(y_true, y_pred)
#     460             else:
#     461                 display_labels = labels
#
# ...
